# %% [markdown]
# # Results

# %% [markdown]
# ## Data augmentation
#
# - Data normalization
# - Random horizontal and vertical flip
# - Random zoom in

# %% [markdown]
# ## Train and eval 4 models, fully connected layer (1024, 2048, Drop out, Batch normalization)

# %%
## Multilayer Perceptron
from IPython.display import Image
Image(filename='./images/label_4_models.png')

# %%
Image(filename='./images/4_models.png')

# %% [markdown]
# ## Best model - fcl of 2048 with dropout

# %%
Image(filename='./images/architecture_network.png')

# %% [markdown]
# ## Submission Model 1

# %%
Image(filename='./images/first_model_results.png')

# %% [markdown]
# ## Second model with more convolutional layers

# %%
Image(filename='./images/model_2_architecture.png')

# %%
Image(filename='./images/compare_model_1_2.png')

# %% [markdown]
# ## Model 1 with different activation functions in the last layer

# %%
Image(filename='./images/label_activation_m1.png')

# %%
Image(filename='./images/3_model_activation.png')

# %% [markdown]
# ## Model 1 with different activation functions in the last layer

# %%
Image(filename='./images/model_2_3_labels.png')

# %%
Image(filename='./images/2_model_with_activation.png')

# %% [markdown]
# ## Model 1 train with train and test dataset

# %%
Image(filename='./images/model1_normal_train_test.png')

# %%
Image(filename='./images/g_model_1_normal_train_test.png')

# %% [markdown]
# ## Submission Model 1 with train and test dataset, score = 0.08919

# %%
Image(filename='./images/model_train_test.png')

# %% [markdown]
# ## Submission Model train with all dataset for 25 epochs, score = 0.8967

# %%
Image(filename='./images/last_submission.png')
